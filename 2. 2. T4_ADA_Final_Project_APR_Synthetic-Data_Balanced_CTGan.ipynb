# %%
# !pip install sdv
# Out:
# Collecting sdv
#   Downloading sdv-1.30.0-py3-none-any.whl.metadata (14 kB)
# Collecting boto3<2.0.0,>=1.28 (from sdv)
#   Downloading boto3-1.42.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<2.0.0,>=1.31 (from sdv)
#   Downloading botocore-1.42.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from sdv) (0.21)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.12/dist-packages (from sdv) (4.67.1)
# Collecting copulas>=0.12.1 (from sdv)
#   Downloading copulas-0.12.3-py3-none-any.whl.metadata (9.5 kB)
# Collecting ctgan>=0.11.1 (from sdv)
#   Downloading ctgan-0.11.1-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.7.0 (from sdv)
#   Downloading deepecho-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.18.2 (from sdv)
#   Downloading rdt-1.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.21.0 (from sdv)
#   Downloading sdmetrics-0.24.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (4.5.0)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (6.0.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.5.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.12/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from copulas>=0.12.1->sdv) (1.16.2)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from ctgan>=0.11.1->sdv) (2.8.0+cu126)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from rdt>=1.18.2->sdv) (1.6.1)
# Collecting Faker!=37.11.0,>=17 (from rdt>=1.18.2->sdv)
#   Downloading faker-38.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.3.0->ctgan>=0.11.1->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.3.0->ctgan>=0.11.1->sdv) (3.0.3)
# Downloading sdv-1.30.0-py3-none-any.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.3/197.3 kB 11.2 MB/s eta 0:00:00
# Downloading boto3-1.42.4-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 21.8 MB/s eta 0:00:00
# Downloading botocore-1.42.4-py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 164.0 MB/s eta 0:00:00
# Downloading copulas-0.12.3-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 7.9 MB/s eta 0:00:00
# Downloading ctgan-0.11.1-py3-none-any.whl (25 kB)
# Downloading deepecho-0.7.0-py3-none-any.whl (27 kB)
# Downloading rdt-1.18.2-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 10.1 MB/s eta 0:00:00
# Downloading sdmetrics-0.24.0-py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.3/198.3 kB 31.0 MB/s eta 0:00:00
# Downloading faker-38.2.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 126.3 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 14.1 MB/s eta 0:00:00
# Installing collected packages: jmespath, Faker, botocore, s3transfer, rdt, copulas, sdmetrics, deepecho, ctgan, boto3, sdv
# Successfully installed Faker-38.2.0 boto3-1.42.4 botocore-1.42.4 copulas-0.12.3 ctgan-0.11.1 deepecho-0.7.0 jmespath-1.0.1 rdt-1.18.2 s3transfer-0.16.0 sdmetrics-0.24.0 sdv-1.30.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import ks_2samp
from scipy.stats import chisquare
from scipy.stats import chi2_contingency
from sdv.metadata import SingleTableMetadata
from sdv.single_table import CTGANSynthesizer

# %% [markdown]
# ### Loading original cleaned dataset

# %%
df_original = pd.read_csv("apr_finaldata.csv")

print(df_original.shape)
df_original.head()
# Out:
# (8856, 11)
#    product_id  discounted_price  actual_price  discount_percentage rating  \
# 0  B07JW9H4J1             399.0        1099.0                 64.0    4.2
# 1  B07JW9H4J1             399.0        1099.0                 64.0    4.2
# 2  B07JW9H4J1             399.0        1099.0                 64.0    4.2
# 3  B07JW9H4J1             399.0        1099.0                 64.0    4.2
# 4  B07JW9H4J1             399.0        1099.0                 64.0    4.2
#
#    rating_count                       user_id       user_name       review_id  \
# 0       24269.0  AG3D6O4STAQKAY2UVGEUV46KN35Q           Manav  R3HXWT0LRP0NMF
# 1       24269.0  AHMY5CWJMMK5BJRBBSNLYT3ONILA    Adarsh gupta  R2AJM3LFTLZHFO
# 2       24269.0  AHCTC6ULH4XB6YHDY6PCH2R772LQ         Sundeep    R6AQJGUP6P86
# 3       24269.0  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  S.Sayeed Ahmed  R1KD19VHEDV0OR
# 4       24269.0  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  jaspreet singh  R3C02RMYQMK6FC
#
#               review_title                                     review_content
# 0                Satisfied     Looks durable Charging is fine tooNo complains
# 1  Charging is really fast                            Charging is really fast
# 2          Value for money                                      good product.
# 3           Product review               Till now satisfied with the quality.
# 4             Good quality  This is a good product . The charging speed is...

# %%
# Select only certain columns that facilitates our purpose for sentimental amalysis and recommendation systems
columns_to_keep = ['product_id', 'user_id', 'rating', 'review_content']
df = df_original[columns_to_keep]

df.head()
# Out:
#    product_id                       user_id rating  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q    4.2
# 1  B07JW9H4J1  AHMY5CWJMMK5BJRBBSNLYT3ONILA    4.2
# 2  B07JW9H4J1  AHCTC6ULH4XB6YHDY6PCH2R772LQ    4.2
# 3  B07JW9H4J1  AGYHHIERNXKA6P5T7CZLXKVPT7IQ    4.2
# 4  B07JW9H4J1  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q    4.2
#
#                                       review_content
# 0     Looks durable Charging is fine tooNo complains
# 1                            Charging is really fast
# 2                                      good product.
# 3               Till now satisfied with the quality.
# 4  This is a good product . The charging speed is...

# %%
df['rating'].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df = df[df['rating'] != '|']

# %%
df['rating'].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df['rating'].dtype
# Out:
# dtype('float64')

# %%
df.columns
df.head()
df['rating'].value_counts(normalize=True) * 100
# Out:
# rating
# 4.1    16.951068
# 4.2    15.662787
# 4.3    15.583682
# 4.0    11.436320
# 3.9     8.543338
# 4.4     8.441632
# 3.8     6.328399
# 4.5     5.243530
# 3.7     2.825178
# 3.6     2.542660
# 3.5     1.988925
# 4.6     1.084868
# 3.3     0.949260
# 3.4     0.745847
# 4.7     0.418126
# 3.1     0.226014
# 3.0     0.214714
# 4.8     0.203413
# 5.0     0.146909
# 3.2     0.124308
# 2.8     0.101706
# 2.9     0.079105
# 2.6     0.079105
# 2.3     0.056504
# 2.0     0.022601
# Name: proportion, dtype: float64

# %% [markdown]
# **Inspect Rating Imbalance**

# %%
rating_dist = (
    df['rating']
    .value_counts(normalize=True)
    .sort_index()
    * 100
)

print("Original rating distribution (%):")
print(rating_dist)
# Out:
# Original rating distribution (%):
# rating
# 2.0     0.022601
# 2.3     0.056504
# 2.6     0.079105
# 2.8     0.101706
# 2.9     0.079105
# 3.0     0.214714
# 3.1     0.226014
# 3.2     0.124308
# 3.3     0.949260
# 3.4     0.745847
# 3.5     1.988925
# 3.6     2.542660
# 3.7     2.825178
# 3.8     6.328399
# 3.9     8.543338
# 4.0    11.436320
# 4.1    16.951068
# 4.2    15.662787
# 4.3    15.583682
# 4.4     8.441632
# 4.5     5.243530
# 4.6     1.084868
# 4.7     0.418126
# 4.8     0.203413
# 5.0     0.146909
# Name: proportion, dtype: float64

# %% [markdown]
# **Creating Bins for Balancing**

# %%
df['rating_bin'] = pd.cut(
    df['rating'],
    bins=[0, 2.5, 3.5, 4.5, 5.1],
    labels=['Low', 'Medium', 'High', 'Very_High'],
    include_lowest=True
)

print("Original rating_bin distribution (%):")
print(df['rating_bin'].value_counts(normalize=True) * 100)
# Out:
# Original rating_bin distribution (%):
# rating_bin
# High         93.558594
# Medium        4.508984
# Very_High     1.853317
# Low           0.079105
# Name: proportion, dtype: float64

# %% [markdown]
# **Oversample to Balance Rating Bins**

# %%
from sklearn.utils import resample

# Size per class
bin_sizes = df['rating_bin'].value_counts()
print("Original bin sizes:")
print(bin_sizes)

max_size = bin_sizes.max()
print("\nTarget size per bin:", max_size)

balanced_chunks = []

for rating_class, group_df in df.groupby('rating_bin'):
    if len(group_df) == 0:
        continue

    group_upsampled = resample(
        group_df,
        replace=True,
        n_samples=max_size,
        random_state=42
    )

    balanced_chunks.append(group_upsampled)

df_balanced = pd.concat(balanced_chunks, ignore_index=True)

print("\nBalanced shape:", df_balanced.shape)

print("\nBalanced rating_bin distribution:")
print(df_balanced['rating_bin'].value_counts(normalize=True) * 100)
# Out:
# Original bin sizes:
# rating_bin
# High         8279
# Medium        399
# Very_High     164
# Low             7
# Name: count, dtype: int64
#
# Target size per bin: 8279
#
# Balanced shape: (33116, 5)
#
# Balanced rating_bin distribution:
# rating_bin
# Low          25.0
# Medium       25.0
# High         25.0
# Very_High    25.0
# Name: proportion, dtype: float64
# /tmp/ipython-input-2141120454.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for rating_class, group_df in df.groupby('rating_bin'):

# %%
df_balanced.head()
# Out:
#    product_id                       user_id  rating  \
# 0  B0BPJBTB3F  AE4Q5XQ7SZW35EEUJKQ3IV2IIBQQ     2.0
# 1  B0BFBNXS94  AE762UDUDQPW4R4QHHTIL7TPTJUA     2.3
# 2  B0BFBNXS94  AEGZSJIUSKF2EKIKGLNKY2CU6WXA     2.3
# 3  B0BPJBTB3F  AE4Q5XQ7SZW35EEUJKQ3IV2IIBQQ     2.0
# 4  B0BFBNXS94  AHAVCLRCPYO2MFYPTURF33N7XH5A     2.3
#
#                                       review_content rating_bin
# 0  Best heater at this price. Quality is very goo...        Low
# 1                             Very very bad portable        Low
# 2            First charge problemSecond motor proble        Low
# 3  Best heater at this price. Quality is very goo...        Low
# 4                cheap quality. doesn’t blend at all        Low

# %% [markdown]
# **Select Columns for CTGAN (Only IDs + Rating)**

# %%
df_ctgan = df_balanced[['product_id', 'user_id', 'rating', 'review_content']].copy()
df_ctgan.head()
# Out:
#    product_id                       user_id  rating  \
# 0  B0BPJBTB3F  AE4Q5XQ7SZW35EEUJKQ3IV2IIBQQ     2.0
# 1  B0BFBNXS94  AE762UDUDQPW4R4QHHTIL7TPTJUA     2.3
# 2  B0BFBNXS94  AEGZSJIUSKF2EKIKGLNKY2CU6WXA     2.3
# 3  B0BPJBTB3F  AE4Q5XQ7SZW35EEUJKQ3IV2IIBQQ     2.0
# 4  B0BFBNXS94  AHAVCLRCPYO2MFYPTURF33N7XH5A     2.3
#
#                                       review_content
# 0  Best heater at this price. Quality is very goo...
# 1                             Very very bad portable
# 2            First charge problemSecond motor proble
# 3  Best heater at this price. Quality is very goo...
# 4                cheap quality. doesn’t blend at all

# %%
df_ctgan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33116 entries, 0 to 33115
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      33116 non-null  object
#  1   user_id         33116 non-null  object
#  2   rating          33116 non-null  float64
#  3   review_content  33116 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Metadata Definition for CTGAN Synthetic Data Generation

# %%
metadata = SingleTableMetadata()

metadata.add_column('product_id', sdtype='id')
metadata.add_column('user_id', sdtype='id')
metadata.add_column('rating', sdtype='numerical')
metadata.add_column('review_content', sdtype='text')


metadata.validate()
metadata.save_to_json("metadata_ctgan.json")
print("✅ Metadata saved as 'metadata_ctgan.json'.")
# Out:
# ✅ Metadata saved as 'metadata_ctgan.json'.

# %% [markdown]
# In this step, **metadata is explicitly defined** for each column to guide the CTGAN model in correctly learning the data structure and variable types.
#
# - `product_id` and `user_id` are defined as **identifier (`id`) types**, indicating unique entity keys.
# - `rating` is defined as a **numerical variable**, allowing CTGAN to model continuous rating behavior.
# - `review_content` is defined as a **text variable**, enabling natural language modeling (if used later).
#
# After defining the schema:
# - The metadata is **validated** to ensure consistency and correctness.
# - The metadata configuration is **saved as a JSON file** (`metadata_ctgan.json`) for reuse in model training and reproducibility.

# %% [markdown]
# **Train CTGAN on Balanced Data**

# %%
from sdv.single_table import CTGANSynthesizer

ctgan_model = CTGANSynthesizer(
    metadata,
    epochs=20,          # you can reduce to 30 if still slow
    batch_size=120,     # ✅ multiple of 10 (pac), avoids AssertionError
    enable_gpu=True,   # ✅ no CUDA OOM, uses CPU
    verbose=True
)

print("⏳ Training CTGAN on balanced data...")
ctgan_model.fit(df_ctgan)
print("✅ CTGAN training completed.")
# Out:
# ⏳ Training CTGAN on balanced data...
# /usr/local/lib/python3.12/dist-packages/sdv/single_table/base.py:168: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# Gen. (2.58) | Discrim. (-0.01): 100%|██████████| 20/20 [08:56<00:00, 26.85s/it]
# ✅ CTGAN training completed.

# %% [markdown]
# Proper tuning of batch size and epochs ensures:
# - Stable GAN convergence,
# - Prevention of runtime assertion errors,
# - Efficient utilization of compute resources.

# %% [markdown]
# **Generate 50× Synthetic Data**

# %%
original_n = len(df)              # original (before balancing)
factor = 50
target_rows = original_n * factor

print("Original rows:", original_n)
print("🎯 Target synthetic rows:", target_rows)

# ----- SAFE CHUNKED SAMPLING -----
chunk_size = 5000   # adjust if needed; 5k is safe for text columns
remaining = target_rows
synthetic_parts = []

while remaining > 0:
    n = min(chunk_size, remaining)
    print(f"Sampling {n} rows... Remaining after this: {remaining - n}")

    batch = ctgan_model.sample(num_rows=n)
    synthetic_parts.append(batch)

    remaining -= n

# Combine all batches
synthetic_ctgan = pd.concat(synthetic_parts, ignore_index=True)

print("Synthetic shape:", synthetic_ctgan.shape)
synthetic_ctgan.head()
# Out:
# Original rows: 8849
# 🎯 Target synthetic rows: 442450
# Sampling 5000 rows... Remaining after this: 437450
# Sampling 5000 rows... Remaining after this: 432450
# Sampling 5000 rows... Remaining after this: 427450
# Sampling 5000 rows... Remaining after this: 422450
# Sampling 5000 rows... Remaining after this: 417450
# Sampling 5000 rows... Remaining after this: 412450
# Sampling 5000 rows... Remaining after this: 407450
# Sampling 5000 rows... Remaining after this: 402450
# Sampling 5000 rows... Remaining after this: 397450
# Sampling 5000 rows... Remaining after this: 392450
# Sampling 5000 rows... Remaining after this: 387450
# Sampling 5000 rows... Remaining after this: 382450
# Sampling 5000 rows... Remaining after this: 377450
# Sampling 5000 rows... Remaining after this: 372450
# Sampling 5000 rows... Remaining after this: 367450
# Sampling 5000 rows... Remaining after this: 362450
# Sampling 5000 rows... Remaining after this: 357450
# Sampling 5000 rows... Remaining after this: 352450
# Sampling 5000 rows... Remaining after this: 347450
# Sampling 5000 rows... Remaining after this: 342450
# Sampling 5000 rows... Remaining after this: 337450
# Sampling 5000 rows... Remaining after this: 332450
# Sampling 5000 rows... Remaining after this: 327450
# Sampling 5000 rows... Remaining after this: 322450
# Sampling 5000 rows... Remaining after this: 317450
# Sampling 5000 rows... Remaining after this: 312450
# Sampling 5000 rows... Remaining after this: 307450
# Sampling 5000 rows... Remaining after this: 302450
# Sampling 5000 rows... Remaining after this: 297450
# Sampling 5000 rows... Remaining after this: 292450
# Sampling 5000 rows... Remaining after this: 287450
# Sampling 5000 rows... Remaining after this: 282450
# Sampling 5000 rows... Remaining after this: 277450
# Sampling 5000 rows... Remaining after this: 272450
# Sampling 5000 rows... Remaining after this: 267450
# Sampling 5000 rows... Remaining after this: 262450
# Sampling 5000 rows... Remaining after this: 257450
# Sampling 5000 rows... Remaining after this: 252450
# Sampling 5000 rows... Remaining after this: 247450
# Sampling 5000 rows... Remaining after this: 242450
# Sampling 5000 rows... Remaining after this: 237450
# Sampling 5000 rows... Remaining after this: 232450
# Sampling 5000 rows... Remaining after this: 227450
# Sampling 5000 rows... Remaining after this: 222450
# Sampling 5000 rows... Remaining after this: 217450
# Sampling 5000 rows... Remaining after this: 212450
# Sampling 5000 rows... Remaining after this: 207450
# Sampling 5000 rows... Remaining after this: 202450
# Sampling 5000 rows... Remaining after this: 197450
# Sampling 5000 rows... Remaining after this: 192450
# Sampling 5000 rows... Remaining after this: 187450
# Sampling 5000 rows... Remaining after this: 182450
# Sampling 5000 rows... Remaining after this: 177450
# Sampling 5000 rows... Remaining after this: 172450
# Sampling 5000 rows... Remaining after this: 167450
# Sampling 5000 rows... Remaining after this: 162450
# Sampling 5000 rows... Remaining after this: 157450
# Sampling 5000 rows... Remaining after this: 152450
# Sampling 5000 rows... Remaining after this: 147450
# Sampling 5000 rows... Remaining after this: 142450
# Sampling 5000 rows... Remaining after this: 137450
# Sampling 5000 rows... Remaining after this: 132450
# Sampling 5000 rows... Remaining after this: 127450
# Sampling 5000 rows... Remaining after this: 122450
# Sampling 5000 rows... Remaining after this: 117450
# Sampling 5000 rows... Remaining after this: 112450
# Sampling 5000 rows... Remaining after this: 107450
# Sampling 5000 rows... Remaining after this: 102450
# Sampling 5000 rows... Remaining after this: 97450
# Sampling 5000 rows... Remaining after this: 92450
# Sampling 5000 rows... Remaining after this: 87450
# Sampling 5000 rows... Remaining after this: 82450
# Sampling 5000 rows... Remaining after this: 77450
# Sampling 5000 rows... Remaining after this: 72450
# Sampling 5000 rows... Remaining after this: 67450
# Sampling 5000 rows... Remaining after this: 62450
# Sampling 5000 rows... Remaining after this: 57450
# Sampling 5000 rows... Remaining after this: 52450
# Sampling 5000 rows... Remaining after this: 47450
# Sampling 5000 rows... Remaining after this: 42450
# Sampling 5000 rows... Remaining after this: 37450
# Sampling 5000 rows... Remaining after this: 32450
# Sampling 5000 rows... Remaining after this: 27450
# Sampling 5000 rows... Remaining after this: 22450
# Sampling 5000 rows... Remaining after this: 17450
# Sampling 5000 rows... Remaining after this: 12450
# Sampling 5000 rows... Remaining after this: 7450
# Sampling 5000 rows... Remaining after this: 2450
# Sampling 2450 rows... Remaining after this: 0
# Synthetic shape: (442450, 4)
#    product_id                       user_id  rating review_content
# 0  B08BCKN299  AGNSJO5LAO5FKSHPW3UDKZQLPONQ     4.2          AAAAA
# 1  B06XDKWLJH  AF3OBVMLY5I6X3IFX2DKIFEYMGNA     4.0          AAAAB
# 2  B08FB2LNSZ  AGK67PKY5YNSHMUNIPVHWPQKPBLA     3.9          AAAAC
# 3  B0B9JZW1SQ  AGYWGDEV2VA2GXFIOTTX545DCUMQ     4.1          AAAAD
# 4  B00LUGTJGO  AG2KSOZBBZY3A37U4Q273OYH2IAQ     4.3          AAAAE

# %% [markdown]
#  The original dataset size (`original_n`) is used as the baseline.
# - A **scaling factor of 50** is applied to define the target number of synthetic rows:
#   - `target_rows = original_n × 50`
# - To avoid **memory overflow issues**, the synthetic data is generated in **fixed-size chunks**:
#   - `chunk_size = 5000` rows per batch,
#   - Sampling continues iteratively until the full target size is reached.
# - Each generated batch is temporarily stored and then **concatenated into a single DataFrame** (`synthetic_ctgan`).
#
# This **chunked sampling strategy** is especially important when:
# - Working with **large synthetic targets**,
# - Handling **text columns** such as `review_content`,
# - Operating under **GPU/CPU memory constraints**.

# %% [markdown]
# **Save Synthetic Data**

# %%
synthetic_ctgan.to_csv("synthetic_ctgan_rating_balanced_50x.csv", index=False)

from google.colab import files
files.download("synthetic_ctgan_rating_balanced_50x.csv")

# %% [markdown]
# A portable, reusable **CTGAN-generated synthetic dataset file** ready for modeling.
